# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
import time
import json
import os
import re


# Den Pfad zur CSV-Datei definieren (angenommen, sie liegt im 'data'-Ordner deines Projekts)
csv_file_path = os.path.join(os.getcwd(), '..', 'Data', 'Dataset.csv')

# CSV-Datei einlesen
df = pd.read_csv(csv_file_path)

#-------------------------------------------------------------------------------
# Publikationen der Länder auf einer Geokarte
# Extrahieren der Länder aus den Affiliations und Bereinigung

# Extrahieren der Länder aus den Affiliations und Bereinigung
def clean_country(entry):
    if pd.isna(entry):
        return None
    # Split bei Semikolon, Komma oder Sonderzeichen und nimm den letzten Teil
    entry = re.split(r'[;,\n]', entry)[-1].strip()
    # Entferne zusätzliche Bezeichnungen oder Sonderzeichen
    entry = re.sub(r'[^a-zA-Z\s]', '', entry).strip()
    return entry

df['Country'] = df['Author Affiliations'].apply(clean_country)

# Liste von bekannten "Nicht-Ländern" (Universitäten, Organisationen, etc.)
non_countries = {
    "Microsoft", "Stellar Sciences", "University of Maryland", "University of Minnesota",
    "Carnegie Mellon University", "Editor-in-Chief of IEEE Computer", "Software Productivity Consortium",
    "University of Calgary", "Software Research Associates", "Brainbot Technologies",
    "Royal Military College of Canada", "University of East London", "Institute of Software Technology",
    "Danfoss", "Construx Software", "RWTH Aachen University", "Oakwood Computing Associates",
    "Software Improvement Group", "Software Engineering Management Associates",
    "Blekinge Institute of Technology", "University of Southern California",
    "Ecole Polytechnique de Montréal", "Polytechnique Montréal",
    "LeroThe Irish Software Research Centre", "Computing Trends",
    "ABB", "Vector Consulting Services",
    "AlcatelLucent", "Microsoft Research",
    # Weitere bekannte Organisationen hinzufügen
}

# Entferne offensichtliche Nicht-Länder
df = df[~df['Country'].isin(non_countries)]

# Mapping von Ländernamen in deiner CSV zu GeoJSON-Ländernamen
country_mapping = {
    "USA": "United States of America",
    "United States": "United States of America",
    "UK": "United Kingdom",
    "Great Britain": "United Kingdom",
    "Deutschland": "Germany",
    "S. Korea": "South Korea",
    "PRChina": "China",
    "P.R. China": "China",
    "PR China": "China",
    "Trkiye": "Turkey",
    "Brasil": "Brazil",
    "México": "Mexico",
    "Mxico": "Mexico",
    "xico": "Mexico",
    "Italia": "Italy",
    "España": "Spain",
    "UAE": "United Arab Emirates",
    "Netherlands": "Netherlands",
    "South Korea": "South Korea",
    "Korea": "South Korea",
    "Republic of Korea": "South Korea",
    "Russia": "Russia",
    "Vereinigte Staaten": "United States of America",
    "Turkey": "Turkey",
    "Austria": "Austria",
    "Ireland": "Ireland",
    "Denmark": "Denmark",
    "Sweden": "Sweden",
    "Finland": "Finland",
    "Norway": "Norway",
    "Portugal": "Portugal",
    "Japan": "Japan",
    "Taiwan": "Taiwan",
    "India": "India",
    "Pakistan": "Pakistan",
    "Bangladesh": "Bangladesh",
    "South Africa": "South Africa",
    "Argentina": "Argentina",
    "Uruguay": "Uruguay",
    "Chile": "Chile",
    "Colombia": "Colombia",
    "Brazil": "Brazil",
    "Italy": "Italy",
    "Germany": "Germany",
    "Spain": "Spain",
    "France": "France",
    "United Kingdom": "United Kingdom",
    "United States of America": "United States of America",
    "The Netherlands": "Netherlands",
    "Macau": "China",
    "CA": "Canada",
    "NL": "Netherlands",
    "CN": "China",
    "JP": "Japan",
    "TW": "Taiwan",
    "IN": "India",
    "BR": "Brazil",
    "DE": "Germany",
    "CH": "Switzerland",
    "KSA": "Saudi Arabia",
    # Weitere Zuordnungen hinzufügen
}

# Mapping anwenden
df['Country'] = df['Country'].replace(country_mapping)

# Aggregation der Publikationen pro Land
country_counts = df['Country'].value_counts().reset_index()
country_counts.columns = ['Country', 'Publication Count']

# Entferne leere oder ungültige Einträge
country_counts = country_counts[country_counts['Country'].notna()]

# Lade GeoJSON-Daten für Ländergrenzen
geojson_url = 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json'
geojson_data = json.loads(pd.read_json(geojson_url).to_json())

# Debugging: Nicht gemappte Länder prüfen
geojson_countries = [feature['properties']['name'] for feature in geojson_data['features'] if 'properties' in feature and 'name' in feature['properties']]
unmatched_countries = set(country_counts['Country']) - set(geojson_countries)
if unmatched_countries:
    print(f"Folgende Länder konnten nicht gemappt werden: {unmatched_countries}")

# Erstelle die Karte
m = folium.Map(location=[20, 0], zoom_start=2)

# Choroplethenkarte hinzufügen
folium.Choropleth(
    geo_data=geojson_data,
    data=country_counts,
    columns=['Country', 'Publication Count'],
    key_on='feature.properties.name',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Publikationen pro Land',
).add_to(m)

# Karte anzeigen
m
# Out:
# Folgende Länder konnten nicht gemappt werden: {'', 'Kuwait', 'Germany', 'KY', 'Leipzig', 'Oregon', 'Italy', 'Monash University', 'Santa Barbara', 'East China Normal University', 'Valencia', 'Czech Republic', 'School of Electrical Engineering and Computer Science at Oregon State University', 'Atlanta', 'Beijing', 'Belgium', 'University of Chicago', 'Cambridge', 'France', 'Spain', 'Vietnam', 'Riverside', 'The Ohio State University', 'UCAS', 'Qatar', 'Slovenia', 'Chile', 'Texas', 'University Ave', 'Raleigh', 'Zagreb', 'Nanjing', 'NE', 'UrbanaChampaign', 'WA', 'Taiwan', 'Australia', 'City University of Hong Kong', 'Norway', 'Shandong University', 'MI', 'Korea University', 'George Mason University', 'Montbonnot SaintMartin', 'The Chinese University of Hong Kong', 'China', 'NJ', 'MA', 'The University of Texas at Dallas', 'Queens University', 'AL', 'NC', 'Estonia', 'Johannes Kepler University Linz', 'Finland', 'School of Cyber Security', 'National University of Defense Technology', 'Author Affiliations', 'University of Chinese Academy of Sciences', 'Saudi Arabia', 'Tunisia', 'Williamsburg', 'Irvine', 'National University of Singapore', 'United States of America', 'Turkey', 'Austria', 'Switzerland', 'Ohio State University', 'US', 'University of Colorado Boulder', 'DC', 'Swinburne University of Technology', 'Huawei Singapore', 'Sweden', 'the University of Southern California', 'Hungary', 'Argentina', 'OH', 'Poland', 'Denmark', 'IL', 'Southern University of Science and Technology', 'Case Western Reserve University', 'RS', 'Cyprus', 'PA', 'Jordan', 'New Zealand', 'Singapore', 'IE', 'Ant Group', 'Canada', 'AR', 'Dallas', 'Inc', 'Ireland', 'India', 'NM', 'Ontario', 'Washington State University', 'SAR', 'TX', 'State Key Lab of Computer Science at ISCAS', 'University of Bonn', 'CO', 'Zhejiang University of Technology', 'KS', 'Egypt', 'University of Science and Technology of China', 'U K', 'DiMIE  University of Basilicata', 'Lebanon', 'Venezuela', 'United Arab Emirates', 'Thailand', 'VA', 'Cluster and Grid Computing Lab', 'Tsinghua University', 'Brazil', 'GA', 'SE', 'UT', 'NA', 'WI', 'DresdenLeipzig', 'South Korea', 'University of Virginia', 'Kirchberg', 'Imperial College London and CONICET', 'INESC TEC', 'University of Illinois at UrbanaChampaign', 'Peking University', 'Xian Jiaotong University', 'Toronto', 'TN', 'Delft', 'University of Electronic Science and Technology of China', 'P R China', 'Kingdom of Saudi Arabia', 'FR', 'Iowa State University', 'London', 'United Kingdom', 'Chinese Academy of Sciences', 'Croatia', 'Microsoft Research at Redmond', 'Japan', 'Israel', 'Federal Aviation Administration', 'Zhejiang University', 'San Antonio', 'University of Texas at El Paso', 'Netherlands', 'University of Zurich', 'University of Michigan', 'Serbia', 'NO', 'ON', 'ROC', 'EPFL', 'CISPA Helmholtz Center for Information Security', 'Portugal', 'Pakistan', 'Purdue University', 'Ann Arbor', 'Tel Aviv University', 'Sun Yatsen University', 'Iran', 'Chainguard', 'NY', 'Malaysia', 'AZ', 'IA', 'Russia', 'Austrialia', 'Louisiana', 'Luxembourg', 'Japa', 'Greece', 'AM', 'Boadilla del Monte', 'Hong Kong', 'Singapore Management University', 'MN', 'South Africa', 'MD'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 141
#     138 m = folium.Map(location=[20, 0], zoom_start=2)
#     140 # Choroplethenkarte hinzufügen
# --> 141 folium.Choropleth(
#     142     geo_data=geojson_data,
#     143     data=country_counts,
#     144     columns=['Country', 'Publication Count'],
#     145     key_on='feature.properties.name',
#     146     fill_color='YlGnBu',
#     147     fill_opacity=0.7,
#     148     line_opacity=0.2,
#     149     legend_name='Publikationen pro Land',
#     150 ).add_to(m)
#     152 # Karte anzeigen
#     153 m
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\folium\features.py:1603, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1596     self.geojson = TopoJson(
#    1597         geo_data,
#    1598         topojson,
#    1599         style_function=style_function,
#    1600         smooth_factor=smooth_factor,
#    1601     )
#    1602 else:
# -> 1603     self.geojson = GeoJson(
#    1604         geo_data,
#    1605         style_function=style_function,
#    1606         smooth_factor=smooth_factor,
#    1607         highlight_function=highlight_function if highlight else None,
#    1608     )
#    1610 self.add_child(self.geojson)
#    1611 if self.color_scale:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\folium\features.py:670, in GeoJson.__init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker, **kwargs)
#     668 self.convert_to_feature_collection()
#     669 if style_function is not None:
# --> 670     self._validate_function(style_function, "style_function")
#     671     self.style_function = style_function
#     672     self.style_map: dict = {}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\folium\features.py:745, in GeoJson._validate_function(self, func, name)
#     742     return
#     744 test_feature = self.data["features"][0]
# --> 745 if not callable(func) or not isinstance(func(test_feature), dict):
#     746     raise ValueError(
#     747         f"{name} should be a function that accepts items from "
#     748         "data['features'] and returns a dictionary."
#     749     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\folium\features.py:1583, in Choropleth.__init__.<locals>.style_function(x)
#    1582 def style_function(x):
# -> 1583     color, opacity = color_scale_fun(x)
#    1584     return {
#    1585         "weight": line_weight,
#    1586         "opacity": line_opacity,
#    (...)
#    1589         "fillColor": color,
#    1590     }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\folium\features.py:1553, in Choropleth.__init__.<locals>.color_scale_fun(x)
#    1552 def color_scale_fun(x):
# -> 1553     key_of_x = self._get_by_key(x, key_on)
#    1554     if key_of_x is None:
#    1555         raise ValueError(f"key_on `{key_on!r}` not found in GeoJSON.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\folium\features.py:1624, in Choropleth._get_by_key(cls, obj, key)
#    1622 if len(key_parts) > 1:
#    1623     new_key = ".".join(key_parts[1:])
# -> 1624     return cls._get_by_key(value, new_key)
#    1625 else:
#    1626     return value
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\folium\features.py:1621, in Choropleth._get_by_key(cls, obj, key)
#    1619     value = obj[int(first_key_part)]
#    1620 else:
# -> 1621     value = obj.get(first_key_part, None)  # type: ignore
#    1622 if len(key_parts) > 1:
#    1623     new_key = ".".join(key_parts[1:])
#
# AttributeError: 'NoneType' object has no attribute 'get'
